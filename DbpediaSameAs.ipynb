# %%
#!pip install rdflib
from rdflib import URIRef, Namespace, Literal
from rdflib.namespace import FOAF as foaf, RDF as rdf, OWL as owl, RDFS as rdfs, XSD

dbo = Namespace('http://dbpedia.org/ontology/')
dbr = 'http://dbpedia.org/resource/'
strprefix = "http://WeatherTourist.org/destination/"
data = Namespace(strprefix) 
schema = Namespace('https://schema.org/')
weat = Namespace('http://www.purl.org/dabgeo/common-domain/weather#/')
bimerr = Namespace('https://bimerr.iot.linkeddata.es/def/weather/') 
w3 = Namespace('http://www.w3.org/2006/time#/')

# %%
#!pip install sparqlwrapper
# Out:
# Requirement already satisfied: sparqlwrapper in c:\users\usuario itc\appdata\local\programs\pythoncodingpack\lib\site-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in c:\users\usuario itc\appdata\local\programs\pythoncodingpack\lib\site-packages (from sparqlwrapper) (6.1.1)
# Requirement already satisfied: setuptools in c:\users\usuario itc\appdata\local\programs\pythoncodingpack\lib\site-packages (from rdflib>=6.1.1->sparqlwrapper) (47.1.0)
# Requirement already satisfied: pyparsing in c:\users\usuario itc\appdata\roaming\python\python38\site-packages (from rdflib>=6.1.1->sparqlwrapper) (2.4.7)
# Requirement already satisfied: isodate in c:\users\usuario itc\appdata\local\programs\pythoncodingpack\lib\site-packages (from rdflib>=6.1.1->sparqlwrapper) (0.6.1)
# Requirement already satisfied: six in c:\users\usuario itc\appdata\roaming\python\python38\site-packages (from isodate->rdflib>=6.1.1->sparqlwrapper) (1.15.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#!pip install pyspotlight 
import spotlight

# %%
from SPARQLWrapper import SPARQLWrapper, JSON, RDF, XML

# %%
endPoint = "http://dbpedia.org/sparql"
sparql = SPARQLWrapper(endPoint)

# %%
from rdflib import Graph

graph = Graph()

# %%
graph.parse('datosRDFProvinces.ttl')
# Out:
# <Graph identifier=Nd0a968f56a644d39b57cf0be8e13f488 (<class 'rdflib.graph.Graph'>)>

# %%
def get_results(query):
    sparql.setReturnFormat(JSON)
    sparql.setQuery(query)

    results = sparql.query().convert()
    return(results)

# %%
def get_comment(candidate_uri):
  query = "select ?comment where {<"+candidate_uri+"> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = \"es\")}}"
  resultados = (get_results(query))
  return(resultados["results"]["bindings"][0]['comment']['value'])

# %%
def get_areaTotal(candidate_uri):
  query = "select ?areaTotal where {<"+candidate_uri+"> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = \"es\")}}"
  resultados = (get_results(query))
  return(resultados["results"]["bindings"][0]['areaTotal']['value'])

# %%
def get_name(candidate_uri):
  query = "select ?name where {<"+candidate_uri+"> foaf:name ?name. Optional{FILTER(LANG(?name) = \"en\")}}"
  resultados = (get_results(query))
  return(resultados["results"]["bindings"][0]['name']['value'])

# %%
def set_country_relationships(country_uri, candidates, graph):
  for candidate in candidates:
    print(owl.sameAs)
    candidate_uri = URIRef(candidate['uri'])
    comment = get_comment(candidate_uri)
    areaTotal = get_areaTotal(candidate_uri)
    name = get_name(candidate_uri)
    graph.add((country_uri, owl.sameAs, candidate_uri))
    graph.add((country_uri, rdfs.comment, Literal(comment)))
    graph.add((country_uri, dbo.areaTotal, Literal(areaTotal, datatype=XSD.double)))
    graph.add((country_uri, foaf.name, Literal(name)))
  return graph

# %%
print(graph.serialize())
# Out:
# @prefix dbo: <http://dbpedia.org/ontology/> .
# @prefix ns1: <http://www.purl.org/dabgeo/common-domain/weather#/> .
# @prefix ns2: <https://bimerr.iot.linkeddata.es/def/weather/> .
# @prefix ns3: <http://www.w3.org/2006/time#/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <https://schema.org/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://WeatherTourist.org/destination/CITY/AgoyÃ¡n> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "AgoyÃ¡n, Tungurahua, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:27:06" ;
#     ns2:RelativeHumidity 78 ;
#     ns2:pressure 1013 ;
#     ns2:temp "294.47"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Tungurahua> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Tungurahua> ;
#     schema:latitude "-1.3833330000000001"^^xsd:float ;
#     schema:longitude "-78.316667"^^xsd:float ;
#     schema:name "AgoyÃ¡n" .
#
# <http://WeatherTourist.org/destination/CITY/Alaques> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Alaques, Cotopaxi Province, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:39" ;
#     ns2:RelativeHumidity 52 ;
#     ns2:pressure 1026 ;
#     ns2:temp "283.98"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/CotopaxiProvince> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/CotopaxiProvince>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "-0.8504952224501332"^^xsd:float ;
#     schema:longitude "-78.4942295266684"^^xsd:float ;
#     schema:name "Alaques" .
#
# <http://WeatherTourist.org/destination/CITY/Amaluza> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Amaluza, Azuay, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:19" ;
#     ns2:RelativeHumidity 86 ;
#     ns2:pressure 1014 ;
#     ns2:temp "289.47"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Azuay> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Azuay>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "-2.6280236938293737"^^xsd:float ;
#     schema:longitude "-78.52552977771"^^xsd:float ;
#     schema:name "Amaluza" .
#
# <http://WeatherTourist.org/destination/CITY/Ambato> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Ambato, Tungurahua, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:27:00" ;
#     ns2:RelativeHumidity 36 ;
#     ns2:pressure 1019 ;
#     ns2:temp "293.38"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Tungurahua> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Tungurahua> ;
#     schema:latitude "-1.257368636311073"^^xsd:float ;
#     schema:longitude "-78.61428555590945"^^xsd:float ;
#     schema:name "Ambato" .
#
# <http://WeatherTourist.org/destination/CITY/Ambuqui> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Ambuqui, Imbabura, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:11" ;
#     ns2:RelativeHumidity 66 ;
#     ns2:pressure 1011 ;
#     ns2:temp "294.33"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Imbabura> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Imbabura> ;
#     schema:latitude "0.40865335230789923"^^xsd:float ;
#     schema:longitude "-78.02079457395298"^^xsd:float ;
#     schema:name "Ambuqui" .
#
# <http://WeatherTourist.org/destination/CITY/Ancayacu> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Ancayacu, Orellana, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:26:42" ;
#     ns2:RelativeHumidity 57 ;
#     ns2:pressure 1007 ;
#     ns2:temp "303.42"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Orellana> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Orellana> ;
#     schema:latitude "-0.7"^^xsd:float ;
#     schema:longitude "-76.0"^^xsd:float ;
#     schema:name "Ancayacu" .
#
# <http://WeatherTourist.org/destination/CITY/AncÃ³n> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "AncÃ³n, Esmeraldas Province, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:25:51" ;
#     ns2:RelativeHumidity 71 ;
#     ns2:pressure 1009 ;
#     ns2:temp "299.76"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:latitude "1.4133065480792586"^^xsd:float ;
#     schema:longitude "-78.85814445217052"^^xsd:float ;
#     schema:name "AncÃ³n" .
#
# <http://WeatherTourist.org/destination/CITY/Angochagua> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Angochagua, Imbabura, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:09" ;
#     ns2:RelativeHumidity 73 ;
#     ns2:pressure 1013 ;
#     ns2:temp "288.83"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Imbabura> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Imbabura> ;
#     schema:latitude "0.22047257877382412"^^xsd:float ;
#     schema:longitude "-78.08225673689789"^^xsd:float ;
#     schema:name "Angochagua" .
#
# <http://WeatherTourist.org/destination/CITY/Apuela> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Apuela, Imbabura, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/moderaterain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:10" ;
#     ns2:RelativeHumidity 90 ;
#     ns2:pressure 1012 ;
#     ns2:temp "289.3"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Imbabura> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Imbabura> ;
#     schema:latitude "0.4244770963065951"^^xsd:float ;
#     schema:longitude "-78.4234976559305"^^xsd:float ;
#     schema:name "Apuela" .
#
# <http://WeatherTourist.org/destination/CITY/Archidona> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Archidona, Archidona, Napo, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:32" ;
#     ns2:RelativeHumidity 88 ;
#     ns2:pressure 1016 ;
#     ns2:temp "283.06"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Napo> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Napo> ;
#     schema:latitude "-0.7331022857819212"^^xsd:float ;
#     schema:longitude "-78.18111418484025"^^xsd:float ;
#     schema:name "Archidona" .
#
# <http://WeatherTourist.org/destination/CITY/Asuncion> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Asuncion, Azuay, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:23" ;
#     ns2:RelativeHumidity 71 ;
#     ns2:pressure 1010 ;
#     ns2:temp "293.74"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Azuay> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Azuay>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "-3.2314363332580736"^^xsd:float ;
#     schema:longitude "-79.24425242245984"^^xsd:float ;
#     schema:name "Asuncion" .
#
# <http://WeatherTourist.org/destination/CITY/Baeza> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Baeza, Napo, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:31" ;
#     ns2:RelativeHumidity 93 ;
#     ns2:pressure 1014 ;
#     ns2:temp "291.45"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Napo> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Napo> ;
#     schema:latitude "-0.464461"^^xsd:float ;
#     schema:longitude "-77.890402"^^xsd:float ;
#     schema:name "Baeza" .
#
# <http://WeatherTourist.org/destination/CITY/Banos> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Banos, Azuay, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:16" ;
#     ns2:RelativeHumidity 74 ;
#     ns2:pressure 1014 ;
#     ns2:temp "281.03"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Azuay> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Azuay>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "-2.98304422627424"^^xsd:float ;
#     schema:longitude "-79.2253062140493"^^xsd:float ;
#     schema:name "Banos" .
#
# <http://WeatherTourist.org/destination/CITY/BaÃ±osdeAguaSanta> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "BaÃ±os de Agua Santa, Tungurahua, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:59" ;
#     ns2:RelativeHumidity 70 ;
#     ns2:pressure 1013 ;
#     ns2:temp "292.93"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Tungurahua> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Tungurahua> ;
#     schema:latitude "-1.4248253180804327"^^xsd:float ;
#     schema:longitude "-78.42557103398643"^^xsd:float ;
#     schema:name "BaÃ±os de Agua Santa" .
#
# <http://WeatherTourist.org/destination/CITY/BorbÃ³n> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "BorbÃ³n, Esmeraldas Province, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:25:42" ;
#     ns2:RelativeHumidity 67 ;
#     ns2:pressure 1009 ;
#     ns2:temp "301.11"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:latitude "1.0170523159891514"^^xsd:float ;
#     schema:longitude "-78.99908601050404"^^xsd:float ;
#     schema:name "BorbÃ³n" .
#
# <http://WeatherTourist.org/destination/CITY/Bunche> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Bunche, Esmeraldas Province, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/scatteredclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:25:48" ;
#     ns2:RelativeHumidity 74 ;
#     ns2:pressure 1010 ;
#     ns2:temp "298.59"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:latitude "0.6377728899093933"^^xsd:float ;
#     schema:longitude "-80.04324443840791"^^xsd:float ;
#     schema:name "Bunche" .
#
# <http://WeatherTourist.org/destination/CITY/Calceta> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Calceta, Manabi, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:26:31" ;
#     ns2:RelativeHumidity 62 ;
#     ns2:pressure 1009 ;
#     ns2:temp "301.7"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Manabi> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Manabi> ;
#     schema:latitude "-0.9196430871990133"^^xsd:float ;
#     schema:longitude "-80.05542641359116"^^xsd:float ;
#     schema:name "Calceta" .
#
# <http://WeatherTourist.org/destination/CITY/Calderon> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Calderon, Esmeraldas Province, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:46" ;
#     ns2:RelativeHumidity 71 ;
#     ns2:pressure 1009 ;
#     ns2:temp "300.43"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:latitude "1.1722213798161465"^^xsd:float ;
#     schema:longitude "-78.76497167044181"^^xsd:float ;
#     schema:name "Calderon" .
#
# <http://WeatherTourist.org/destination/CITY/Canoa> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Canoa, Manabi, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:26:22" ;
#     ns2:RelativeHumidity 79 ;
#     ns2:pressure 1010 ;
#     ns2:temp "297.14"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Manabi> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Manabi> ;
#     schema:latitude "-0.39064781401659154"^^xsd:float ;
#     schema:longitude "-80.40232240309916"^^xsd:float ;
#     schema:name "Canoa" .
#
# <http://WeatherTourist.org/destination/CITY/Carolina> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Carolina, Imbabura, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/moderaterain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:15" ;
#     ns2:RelativeHumidity 86 ;
#     ns2:pressure 1012 ;
#     ns2:temp "288.3"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Imbabura> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Imbabura> ;
#     schema:latitude "0.6534333630952722"^^xsd:float ;
#     schema:longitude "-78.2306964660524"^^xsd:float ;
#     schema:name "Carolina" .
#
# <http://WeatherTourist.org/destination/CITY/Chical> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Chical, Carchi, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/moderaterain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:27" ;
#     ns2:RelativeHumidity 96 ;
#     ns2:pressure 1011 ;
#     ns2:temp "291.65"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Carchi> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Carchi>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "0.9962967586680864"^^xsd:float ;
#     schema:longitude "-78.26126387737317"^^xsd:float ;
#     schema:name "Chical" .
#
# <http://WeatherTourist.org/destination/CITY/Chinca> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Chinca, Esmeraldas Province, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/clearsky> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clear> ;
#     ns3:inDateTime "2022-06-06 15:25:43" ;
#     ns2:RelativeHumidity 60 ;
#     ns2:pressure 1009 ;
#     ns2:temp "300.97"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:latitude "0.7745730911180627"^^xsd:float ;
#     schema:longitude "-79.56395387285635"^^xsd:float ;
#     schema:name "Chinca" .
#
# <http://WeatherTourist.org/destination/CITY/Chuga> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Chuga, Imbabura, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:14" ;
#     ns2:RelativeHumidity 72 ;
#     ns2:pressure 1012 ;
#     ns2:temp "287.05"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Imbabura> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Imbabura> ;
#     schema:latitude "0.3639697181852287"^^xsd:float ;
#     schema:longitude "-77.87578585200076"^^xsd:float ;
#     schema:name "Chuga" .
#
# <http://WeatherTourist.org/destination/CITY/ChumblÃ­n> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "ChumblÃ­n, Azuay, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:25" ;
#     ns2:RelativeHumidity 73 ;
#     ns2:pressure 1012 ;
#     ns2:temp "281.77"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Azuay> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Azuay>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "-3.096483769763451"^^xsd:float ;
#     schema:longitude "-79.24640754898066"^^xsd:float ;
#     schema:name "ChumblÃ­n" .
#
# <http://WeatherTourist.org/destination/CITY/Chura> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Chura, Esmeraldas Province, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/scatteredclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:25:45" ;
#     ns2:RelativeHumidity 57 ;
#     ns2:pressure 1009 ;
#     ns2:temp "302.53"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:latitude "0.5265675420449156"^^xsd:float ;
#     schema:longitude "-79.45746994881267"^^xsd:float ;
#     schema:name "Chura" .
#
# <http://WeatherTourist.org/destination/CITY/Coca> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Coca, Orellana, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/scatteredclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:26:39" ;
#     ns2:RelativeHumidity 66 ;
#     ns2:pressure 1010 ;
#     ns2:temp "303.09"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Orellana> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Orellana> ;
#     schema:latitude "-0.4394828809942288"^^xsd:float ;
#     schema:longitude "-76.98901875787874"^^xsd:float ;
#     schema:name "Coca" .
#
# <http://WeatherTourist.org/destination/CITY/Cojimies> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Cojimies, Manabi, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/scatteredclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:26:24" ;
#     ns2:RelativeHumidity 72 ;
#     ns2:pressure 1009 ;
#     ns2:temp "299.27"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Manabi> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Manabi> ;
#     schema:latitude "0.22962498953395402"^^xsd:float ;
#     schema:longitude "-79.86812514295191"^^xsd:float ;
#     schema:name "Cojimies" .
#
# <http://WeatherTourist.org/destination/CITY/Concepcion> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Concepcion, Carchi, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:33" ;
#     ns2:RelativeHumidity 81 ;
#     ns2:pressure 1012 ;
#     ns2:temp "288.12"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Carchi> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Carchi>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "0.6580237153967372"^^xsd:float ;
#     schema:longitude "-78.1108533544168"^^xsd:float ;
#     schema:name "Concepcion" .
#
# <http://WeatherTourist.org/destination/CITY/Cononaco> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Cononaco, Orellana, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:47" ;
#     ns2:RelativeHumidity 59 ;
#     ns2:pressure 1008 ;
#     ns2:temp "302.91"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Orellana> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Orellana> ;
#     schema:latitude "-1.053168958935888"^^xsd:float ;
#     schema:longitude "-76.06921234676825"^^xsd:float ;
#     schema:name "Cononaco" .
#
# <http://WeatherTourist.org/destination/CITY/Cosanga> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Cosanga, Napo, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:36" ;
#     ns2:RelativeHumidity 84 ;
#     ns2:pressure 1013 ;
#     ns2:temp "290.69"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Napo> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Napo> ;
#     schema:latitude "-0.6"^^xsd:float ;
#     schema:longitude "-77.866699"^^xsd:float ;
#     schema:name "Cosanga" .
#
# <http://WeatherTourist.org/destination/CITY/Cotalo> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Cotalo, Tungurahua, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/scatteredclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:27:08" ;
#     ns2:RelativeHumidity 64 ;
#     ns2:pressure 1012 ;
#     ns2:temp "296.71"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Tungurahua> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Tungurahua> ;
#     schema:latitude "-1.4385247880729364"^^xsd:float ;
#     schema:longitude "-78.50635540640647"^^xsd:float ;
#     schema:name "Cotalo" .
#
# <http://WeatherTourist.org/destination/CITY/Cotundo> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Cotundo, Napo, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:37" ;
#     ns2:RelativeHumidity 73 ;
#     ns2:pressure 1012 ;
#     ns2:temp "297.17"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Napo> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Napo> ;
#     schema:latitude "-0.6982762739500987"^^xsd:float ;
#     schema:longitude "-77.82663614801466"^^xsd:float ;
#     schema:name "Cotundo" .
#
# <http://WeatherTourist.org/destination/CITY/Crucita> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Crucita, Manabi, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:26:23" ;
#     ns2:RelativeHumidity 73 ;
#     ns2:pressure 1011 ;
#     ns2:temp "298.25"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Manabi> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Manabi> ;
#     schema:latitude "-0.8848371682876117"^^xsd:float ;
#     schema:longitude "-80.53297990751143"^^xsd:float ;
#     schema:name "Crucita" .
#
# <http://WeatherTourist.org/destination/CITY/Cuenca> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Cuenca, Cuenca, Azuay, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:17:56" ;
#     ns2:RelativeHumidity 88 ;
#     ns2:pressure 1023 ;
#     ns2:temp "288.03"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Azuay> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Azuay>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "-2.898429"^^xsd:float ;
#     schema:longitude "-79.00612"^^xsd:float ;
#     schema:name "Cuenca" .
#
# <http://WeatherTourist.org/destination/CITY/CumbayÃ¡> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "CumbayÃ¡, Pichincha, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/thunderstorm> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Thunderstorm> ;
#     ns3:inDateTime "2022-06-06 15:26:51" ;
#     ns2:RelativeHumidity 63 ;
#     ns2:pressure 1022 ;
#     ns2:temp "292.44"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Pichincha> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Pichincha> ;
#     schema:latitude "-0.2"^^xsd:float ;
#     schema:longitude "-78.433296"^^xsd:float ;
#     schema:name "CumbayÃ¡" .
#
# <http://WeatherTourist.org/destination/CITY/Cuyuja> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Cuyuja, Napo, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:35" ;
#     ns2:RelativeHumidity 93 ;
#     ns2:pressure 1015 ;
#     ns2:temp "284.57"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Napo> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Napo> ;
#     schema:latitude "-0.42319353294746587"^^xsd:float ;
#     schema:longitude "-78.06502376372069"^^xsd:float ;
#     schema:name "Cuyuja" .
#
# <http://WeatherTourist.org/destination/CITY/Daule> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Daule, Daule, Guayas, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:26:03" ;
#     ns2:RelativeHumidity 62 ;
#     ns2:pressure 1008 ;
#     ns2:temp "300.16"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Guayas> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Guayas> ;
#     schema:latitude "-1.86218"^^xsd:float ;
#     schema:longitude "-79.977669"^^xsd:float ;
#     schema:name "Daule" .
#
# <http://WeatherTourist.org/destination/CITY/Dayuma> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Dayuma, Orellana, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:26:46" ;
#     ns2:RelativeHumidity 50 ;
#     ns2:pressure 1007 ;
#     ns2:temp "302.86"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Orellana> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Orellana> ;
#     schema:latitude "-0.7127089671791028"^^xsd:float ;
#     schema:longitude "-76.77792081262214"^^xsd:float ;
#     schema:name "Dayuma" .
#
# <http://WeatherTourist.org/destination/CITY/Derna> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Derna, Coca, Orellana, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/scatteredclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:26:48" ;
#     ns2:RelativeHumidity 48 ;
#     ns2:pressure 1007 ;
#     ns2:temp "303.29"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Orellana> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Orellana> ;
#     schema:latitude "-0.45"^^xsd:float ;
#     schema:longitude "-76.733299"^^xsd:float ;
#     schema:name "Derna" .
#
# <http://WeatherTourist.org/destination/CITY/Duran> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Duran, Guayas, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:25:57" ;
#     ns2:RelativeHumidity 69 ;
#     ns2:pressure 1010 ;
#     ns2:temp "300.19"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Guayas> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Guayas> ;
#     schema:latitude "-2.2301510285072026"^^xsd:float ;
#     schema:longitude "-79.78263120943423"^^xsd:float ;
#     schema:name "Duran" .
#
# <http://WeatherTourist.org/destination/CITY/ElAngel> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "El Angel, Carchi, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:28" ;
#     ns2:RelativeHumidity 75 ;
#     ns2:pressure 1012 ;
#     ns2:temp "287.4"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Carchi> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Carchi>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "0.6434494730829735"^^xsd:float ;
#     schema:longitude "-77.97236077353128"^^xsd:float ;
#     schema:name "El Angel" .
#
# <http://WeatherTourist.org/destination/CITY/ElCarmelo> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "El Carmelo, Carchi, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:31" ;
#     ns2:RelativeHumidity 79 ;
#     ns2:pressure 1013 ;
#     ns2:temp "287.98"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Carchi> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Carchi>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "0.6595225193010943"^^xsd:float ;
#     schema:longitude "-77.60754146546024"^^xsd:float ;
#     schema:name "El Carmelo" .
#
# <http://WeatherTourist.org/destination/CITY/ElDorado> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "El Dorado, Orellana, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/scatteredclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:26:49" ;
#     ns2:RelativeHumidity 66 ;
#     ns2:pressure 1010 ;
#     ns2:temp "302.98"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Orellana> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Orellana> ;
#     schema:latitude "-0.531771605431511"^^xsd:float ;
#     schema:longitude "-76.92054957460954"^^xsd:float ;
#     schema:name "El Dorado" .
#
# <http://WeatherTourist.org/destination/CITY/Enokanqui> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Enokanqui, Orellana, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:26:44" ;
#     ns2:RelativeHumidity 49 ;
#     ns2:pressure 1007 ;
#     ns2:temp "302.97"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Orellana> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Orellana> ;
#     schema:latitude "-0.22876749939556276"^^xsd:float ;
#     schema:longitude "-76.83712247685918"^^xsd:float ;
#     schema:name "Enokanqui" .
#
# <http://WeatherTourist.org/destination/CITY/EstrellaYacu> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Estrella Yacu, Orellana, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/scatteredclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:26:44" ;
#     ns2:RelativeHumidity 66 ;
#     ns2:pressure 1010 ;
#     ns2:temp "303.11"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Orellana> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Orellana> ;
#     schema:latitude "-0.433333"^^xsd:float ;
#     schema:longitude "-77.116667"^^xsd:float ;
#     schema:name "Estrella Yacu" .
#
# <http://WeatherTourist.org/destination/CITY/Galera> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Galera, Esmeraldas Province, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:25:47" ;
#     ns2:RelativeHumidity 74 ;
#     ns2:pressure 1010 ;
#     ns2:temp "297.92"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/EsmeraldasProvince> ;
#     schema:latitude "0.79859"^^xsd:float ;
#     schema:longitude "-80.062073"^^xsd:float ;
#     schema:name "Galera" .
#
# <http://WeatherTourist.org/destination/CITY/GarcÃ­aMoreno> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "GarcÃ­a Moreno, Imbabura, Ecuador",
#         "GarcÃ­a Moreno, Orellana, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/moderaterain>,
#         <http://WeatherTourist.org/destination/scatteredclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds>,
#         <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:08",
#         "2022-06-06 15:26:41" ;
#     ns2:RelativeHumidity 66,
#         88 ;
#     ns2:pressure 1010,
#         1011 ;
#     ns2:temp "293.36"^^xsd:float,
#         "302.79"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Imbabura>,
#         <http://WeatherTourist.org/destination/Orellana> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Imbabura>,
#         <http://WeatherTourist.org/destination/Orellana> ;
#     schema:latitude "-0.5683164243513964"^^xsd:float,
#         "0.29808219457766194"^^xsd:float ;
#     schema:longitude "-78.78756682843544"^^xsd:float,
#         "-77.0219717099203"^^xsd:float ;
#     schema:name "GarcÃ­a Moreno" .
#
# <http://WeatherTourist.org/destination/CITY/Giron> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Giron, Azuay, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:23" ;
#     ns2:RelativeHumidity 69 ;
#     ns2:pressure 1012 ;
#     ns2:temp "284.98"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Azuay> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Azuay>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "-3.14828"^^xsd:float ;
#     schema:longitude "-79.103828"^^xsd:float ;
#     schema:name "Giron" .
#
# <http://WeatherTourist.org/destination/CITY/Gualel> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Gualel, Loja Province, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:26:18" ;
#     ns2:RelativeHumidity 71 ;
#     ns2:pressure 1011 ;
#     ns2:temp "296.11"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/LojaProvince> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/LojaProvince> ;
#     schema:latitude "-3.7536272587413535"^^xsd:float ;
#     schema:longitude "-79.37310779298699"^^xsd:float ;
#     schema:name "Gualel" .
#
# <http://WeatherTourist.org/destination/CITY/Guangopolo> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Guangopolo, Pichincha, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/thunderstorm> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Thunderstorm> ;
#     ns3:inDateTime "2022-06-06 15:26:58" ;
#     ns2:RelativeHumidity 63 ;
#     ns2:pressure 1022 ;
#     ns2:temp "291.59"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Pichincha> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Pichincha> ;
#     schema:latitude "-0.25290948306019445"^^xsd:float ;
#     schema:longitude "-78.43763959454907"^^xsd:float ;
#     schema:name "Guangopolo" .
#
# <http://WeatherTourist.org/destination/CITY/Guanguaje> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Guanguaje, Cotopaxi Province, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:36" ;
#     ns2:RelativeHumidity 76 ;
#     ns2:pressure 1012 ;
#     ns2:temp "285.48"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/CotopaxiProvince> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/CotopaxiProvince>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "-0.8989258589556418"^^xsd:float ;
#     schema:longitude "-78.84193959966555"^^xsd:float ;
#     schema:name "Guanguaje" .
#
# <http://WeatherTourist.org/destination/CITY/Guayaquil> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Guayaquil, Guayaquil, Guayas, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/overcastclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:25:55" ;
#     ns2:RelativeHumidity 59 ;
#     ns2:pressure 1008 ;
#     ns2:temp "299.94"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Guayas> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Guayas> ;
#     schema:latitude "-2.2881120566221615"^^xsd:float ;
#     schema:longitude "-80.08944867983072"^^xsd:float ;
#     schema:name "Guayaquil" .
#
# <http://WeatherTourist.org/destination/CITY/Guayllabamba> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Guayllabamba, Pichincha, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/thunderstorm> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Thunderstorm> ;
#     ns3:inDateTime "2022-06-06 15:26:54" ;
#     ns2:RelativeHumidity 63 ;
#     ns2:pressure 1022 ;
#     ns2:temp "293.71"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Pichincha> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Pichincha> ;
#     schema:latitude "-0.05410230128899479"^^xsd:float ;
#     schema:longitude "-78.34332932772412"^^xsd:float ;
#     schema:name "Guayllabamba" .
#
# <http://WeatherTourist.org/destination/CITY/GÃ¼el> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "GÃ¼el, Azuay, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:22" ;
#     ns2:RelativeHumidity 75 ;
#     ns2:pressure 1014 ;
#     ns2:temp "287.94"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Azuay> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Azuay>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "-3.0263134490816954"^^xsd:float ;
#     schema:longitude "-78.76281088049963"^^xsd:float ;
#     schema:name "GÃ¼el" .
#
# <http://WeatherTourist.org/destination/CITY/HaciendaCusubambito> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Hacienda Cusubambito, Cotopaxi Province, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:37" ;
#     ns2:RelativeHumidity 40 ;
#     ns2:pressure 1025 ;
#     ns2:temp "290.94"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/CotopaxiProvince> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/CotopaxiProvince>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "-1.083792"^^xsd:float ;
#     schema:longitude "-78.63399199999999"^^xsd:float ;
#     schema:name "Hacienda Cusubambito" .
#
# <http://WeatherTourist.org/destination/CITY/Huaca> a dbo:City,
#         schema:TouristDestination ;
#     rdfs:label "Huaca, Carchi, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/lightrain> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Rain> ;
#     ns3:inDateTime "2022-06-06 15:25:29" ;
#     ns2:RelativeHumidity 63 ;
#     ns2:pressure 1029 ;
#     ns2:temp "288.37"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Carchi> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Carchi>,
#         <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:latitude "0.630755298229135"^^xsd:float ;
#     schema:longitude "-77.72425658004336"^^xsd:float ;
#     schema:name "Huaca" .
#
# <http://WeatherTourist.org/destination/CITY/Ibarra> a dbo:City,
# ...
#     ns3:inDateTime "2022-06-06 15:25:57" ;
#     ns2:RelativeHumidity 69 ;
#     ns2:pressure 1010 ;
#     ns2:temp "300.1"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Guayas> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Guayas> ;
#     schema:latitude "-2.162866547445079"^^xsd:float ;
#     schema:longitude "-79.90834126423356"^^xsd:float ;
#     schema:name "Urdesa" .
#
# <http://WeatherTourist.org/destination/REGION/DaphneIslands> a schema:TouristDestination ;
#     rdfs:label "Daphne Islands, Galapagos, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:25:55" ;
#     ns2:RelativeHumidity 78 ;
#     ns2:pressure 1012 ;
#     ns2:temp "297.49"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Galapagos> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Galapagos> ;
#     schema:latitude "-0.4095701301323356"^^xsd:float ;
#     schema:longitude "-90.35974366962695"^^xsd:float ;
#     schema:name "Daphne Islands" .
#
# <http://WeatherTourist.org/destination/REGION/IslaIsabela> a schema:TouristDestination ;
#     rdfs:label "Isla Isabela, Galapagos, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:25:53" ;
#     ns2:RelativeHumidity 62 ;
#     ns2:pressure 1011 ;
#     ns2:temp "293.15"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Galapagos> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Galapagos> ;
#     schema:latitude "-0.829237"^^xsd:float ;
#     schema:longitude "-91.1353"^^xsd:float ;
#     schema:name "Isla Isabela" .
#
# <http://WeatherTourist.org/destination/REGION/SantaCruzIsland> a schema:TouristDestination ;
#     rdfs:label "Santa Cruz Island, Galapagos, Ecuador" ;
#     ns1:WeatherCondition <http://WeatherTourist.org/destination/brokenclouds> ;
#     ns1:WeatherState <http://WeatherTourist.org/destination/Clouds> ;
#     ns3:inDateTime "2022-06-06 15:25:52" ;
#     ns2:RelativeHumidity 87 ;
#     ns2:pressure 1011 ;
#     ns2:temp "292.47"^^xsd:float ;
#     schema:Country <http://WeatherTourist.org/destination/Ecuador> ;
#     schema:State <http://WeatherTourist.org/destination/Galapagos> ;
#     schema:containedInPlace <http://WeatherTourist.org/destination/Ecuador>,
#         <http://WeatherTourist.org/destination/Galapagos> ;
#     schema:latitude "-0.6332870501456088"^^xsd:float ;
#     schema:longitude "-90.37389323662065"^^xsd:float ;
#     schema:name "Santa Cruz Island" .
#
# <http://WeatherTourist.org/destination/Clear> a ns1:WeatherState ;
#     ns1:hasWeatherCondition "Clear" .
#
# <http://WeatherTourist.org/destination/Snow> a ns1:WeatherState ;
#     ns1:hasWeatherCondition "Clouds",
#         "Rain",
#         "Snow" .
#
# <http://WeatherTourist.org/destination/clearsky> a ns1:WeatherCondition ;
#     ns1:hasWeatherCondition "clear sky" .
#
# <http://WeatherTourist.org/destination/snow> a ns1:WeatherCondition ;
#     ns1:hasWeatherCondition "snow" .
#
# <http://WeatherTourist.org/destination/fewclouds> a ns1:WeatherCondition ;
#     ns1:hasWeatherCondition "few clouds" .
#
# <http://WeatherTourist.org/destination/Thunderstorm> a ns1:WeatherState ;
#     ns1:hasWeatherCondition "Thunderstorm" .
#
# <http://WeatherTourist.org/destination/thunderstorm> a ns1:WeatherCondition ;
#     ns1:hasWeatherCondition "thunderstorm" .
#
# <http://WeatherTourist.org/destination/overcastclouds> a ns1:WeatherCondition ;
#     ns1:hasWeatherCondition "overcast clouds" .
#
# <http://WeatherTourist.org/destination/moderaterain> a ns1:WeatherCondition ;
#     ns1:hasWeatherCondition "moderate rain" .
#
# <http://WeatherTourist.org/destination/scatteredclouds> a ns1:WeatherCondition ;
#     ns1:hasWeatherCondition "scattered clouds" .
#
# <http://WeatherTourist.org/destination/CotopaxiProvince> a schema:State ;
#     rdfs:label " Cotopaxi Province" ;
#     dbo:areaTotal 6.10823e+09 ;
#     rdfs:comment "La Provincia de Cotopaxi (pronunciado [ko.toˈpak.si]) es una de las 24 provincias que conforman la República del Ecuador, situada al centro del país, en la región interandina o Sierra, principalmente sobre la hoya de Patate en el este y en los flancos externos de la cordillera occidental en el oeste. Su capital administrativa es la ciudad de Latacunga, la cual además es su urbe más grande y poblada. Ocupa un territorio de unos 6.085 km², siendo la décima quinta provincia del país por extensión. Limita al norte con Pichincha, al sur con Tungurahua y Bolívar, por el occidente con Los Ríos y al oriente con Napo." ;
#     owl:sameAs <https://dbpedia.org/page/Cotopaxi_Province> .
#
# <http://WeatherTourist.org/destination/LojaProvince> a schema:State ;
#     rdfs:label " Loja Province" ;
#     dbo:areaTotal 1.10627e+10 ;
#     rdfs:comment "La Provincia de Loja es una de las 24 provincias que conforman la República del Ecuador, situada en el sur del país, en la zona geográfica conocida como región interandina o sierra. Su capital administrativa es la ciudad de Loja, la cual además es su urbe más grande y poblada. Ocupa un territorio de unos 11 066 km², siendo la novena provincia del país por extensión. Limita con las provincia de El Oro al noroeste; con la provincia de Zamora Chinchipe al este; con la provincia del Azuay al norte; al sur con las provincias peruanas de Sullana y Ayabaca y al oeste con las provincias de Zarumilla y Tumbes, también pertenecientes al Perú." ;
#     owl:sameAs <http://dbpedia.org/resource/Loja_Province> .
#
# <http://WeatherTourist.org/destination/Azuay> a schema:State ;
#     rdfs:label " Azuay" ;
#     dbo:areaTotal 8.30958e+09 ;
#     rdfs:comment "La provincia de Azuay es una de las 24 provincias que conforman la República de Ecuador, situada en el sur del país, en la zona geográfica conocida como región interandina o sierra, principalmente sobre la hoya de Paute en el noreste y la hoya de Jubones en el suroccidente. Su capital administrativa es la ciudad de Cuenca, la cual además es su urbe más grande y poblada. Ocupa un territorio de unos 8.189 km², siendo la duodécima provincia del país por extensión. Limita al norte con Cañar, al sur con Loja, por el occidente con Guayas, al suroccidente con El Oro, al este con Morona Santiago y al sureste con Zamora Chinchipe." ;
#     owl:sameAs <https://dbpedia.org/page/Azuay_Province> .
#
# <http://WeatherTourist.org/destination/Carchi> a schema:State ;
#     rdfs:label " Carchi" ;
#     dbo:areaTotal 3.78045e+09 ;
#     rdfs:comment "La provincia de Carchi es una de las 24 provincias que conforman la República del Ecuador, situada en el norte del país, en la zona geográfica conocida como región interandina o sierra, principalmente sobre el nudo de los Pastos al noreste, la hoya de Chota en el sur y en los flancos externos de la cordillera occidental en el oeste. Su capital es la ciudad de Tulcán, la cual además es su urbe más grande y poblada. Ocupa un territorio de unos 3.790 km², siendo la cuarta provincia del país más pequeña por extensión, detrás de Tungurahua, Cañar y Santa Elena. Limita al sur con Imbabura, por el occidente con Esmeraldas, al este con Sucumbíos y por el norte con el departamento de Nariño perteneciente a Colombia." ;
#     owl:sameAs <https://dbpedia.org/page/Carchi_Province> .
#
# <http://WeatherTourist.org/destination/EsmeraldasProvince> a schema:State ;
#     rdfs:label " Esmeraldas Province" ;
#     dbo:areaTotal 1.61322e+10 ;
#     rdfs:comment "Esmeraldas, también conocida como San Mateo de las Esmeraldas, es una ciudad ecuatoriana; cabecera del cantón homónimo y capital de la Provincia de Esmeraldas, así como la urbe más grande y poblada de la misma. Se localiza en la orilla derecha de la desembocadura del río Esmeraldas, al norte de la región litoral del Ecuador, a una altitud de 15 m s. n. m. y con un clima tropical de sabana de 27 °C en promedio." ;
#     owl:sameAs <https://dbpedia.org/page/Esmeraldas_Province> .
#
# <http://WeatherTourist.org/destination/Galapagos> a schema:State ;
#     rdfs:label " Galapagos" ;
#     dbo:areaTotal 4.5e+10 ;
#     rdfs:comment "La Provincia de Galápagos es una de las 24 provincias que conforman la República del Ecuador. Está localizada a 1000 km de la costa del Ecuador continental. Su territorio está conformado por el Archipiélago de Colón, también conocido como \"Islas Galápagos\", del cual adopta su nombre. En total son 13 islas grandes, 6 medianas y 107 islotes y rocas las que conforman el archipiélago. La capital administrativa es la ciudad de Puerto Baquerizo Moreno mientras que la urbe más extensa y poblada es Puerto Ayora. Ocupa un territorio de unos 8.010 km²." ;
#     owl:sameAs <http://dbpedia.org/resource/Gal%C3%A1pagos_Province> .
#
# <http://WeatherTourist.org/destination/Guayas> a schema:State ;
#     rdfs:label " Guayas" ;
#     dbo:areaTotal 1.54304e+10 ;
#     rdfs:comment "Guayas, oficialmente Provincia del Guayas, es una de las 24 provincias que conforman la República del Ecuador, localizada en la región litoral del país, al suroeste del mismo. Su capital es la ciudad de Guayaquil.La provincia es el mayor centro comercial ,Economico e Industrial de Ecuador. Con sus 4,3 millones de habitantes, Guayas es la provincia más poblada del país y contiene el 24,5% de la población de la República. La provincia toma el nombre del río más caudaloso e importante de su territorio, el río Guayas. Con sus 2,5 millones de habitantes (más del 68% de la población provincial), la ciudad de Guayaquil no es sólo la ciudad más poblada de la provincia, sino también lasegunda más poblada de Ecuador." ;
#     owl:sameAs <http://dbpedia.org/resource/Guayas_Province> .
#
# <http://WeatherTourist.org/destination/Imbabura> a schema:State ;
#     rdfs:label " Imbabura" ;
#     dbo:areaTotal 4.58751e+09 ;
#     rdfs:comment "La Provincia de Imbabura es una de las 24 provincias que conforman la República del Ecuador, situada en el norte del país, en la zona geográfica conocida como región interandina o sierra, principalmente sobre la hoya de Chota en el este y en los flancos externos de la cordillera occidental en el oeste. Su capital administrativa es la ciudad de Ibarra, la cual además es su urbe más grande y poblada y es también conocida como Ibarra la ciudad blanca. Imbabura ocupa un territorio de unos 4.611 km², siendo la décima octava provincia del país por extensión. Limita al norte con Carchi, al sur con Pichincha, por el occidente con Esmeraldas y al este con Sucumbíos." ;
#     owl:sameAs <http://dbpedia.org/resource/Imbabura_Province> .
#
# <http://WeatherTourist.org/destination/Manabi> a schema:State ;
#     rdfs:label " Manabi" ;
#     dbo:areaTotal 1.89396e+10 ;
#     rdfs:comment "La Provincia de Manabí es una de las 24 provincias que conforman la República del Ecuador, situada al occidente del país, en la zona geográfica conocida como región Litoral o Costa. Su capital administrativa es la ciudad de Portoviejo. Ocupa un territorio de unos 19.427 km², siendo la cuarta provincia del país por extensión, detrás de Pastaza, Morona Santiago y Orellana. Además del territorio continental, pertenecen a la jurisdicción de la provincia la Isla de la Plata y la Isla Salango. Limita al norte con Esmeraldas, por el este con Santo Domingo de los Tsáchilas y Los Ríos, al sur con Santa Elena, al este y al sur con Guayas y al oeste con el océano Pacífico a lo largo de una franja marítima de unos 350 kilómetros." ;
#     owl:sameAs <http://dbpedia.org/resource/Manab%C3%AD_Province> .
#
# <http://WeatherTourist.org/destination/Napo> a schema:State ;
#     rdfs:label " Napo" ;
#     dbo:areaTotal 1.25425e+10 ;
#     rdfs:comment "La Provincia de Napo es una de las 24 provincias que conforman la República del Ecuador, situada al centro norte del país, en la zona geográfica conocida como región amazónica, principalmente en los flancos externos de la cordillera occidental en el norte y oeste y la extensa llanura amazónica al sur. Su capital administrativa es la ciudad de Tena la cual es su urbe más grande y poblada siendo uno de los cuatro cantones que conforman la provincia. Ocupa un territorio de unos 12 476 km², siendo la octava provincia del país por extensión. Limita al norte con Sucumbíos, al sur con Pastaza, al oeste con Pichincha, Cotopaxi y Tungurahua y al este con Orellana." ;
#     owl:sameAs <https://dbpedia.org/resource/Napo_Province> .
#
# <http://WeatherTourist.org/destination/Orellana> a schema:State ;
#     rdfs:label " Orellana" ;
#     dbo:areaTotal 2.16921e+10 ;
#     rdfs:comment "La Provincia de Orellana es una de las 24 provincias que conforman la República del Ecuador, situada al nororiente del país, en la zona geográfica conocida como región amazónica. Su capital administrativa es la ciudad de Coca, la cual además es su urbe más grande y poblada. Ocupa un territorio de unos 21.691 km², siendo la tercera provincia del país por extensión, detrás de Pastaza y Morona Santiago. Limita al norte con la provincia de Sucumbíos, por el occidente con la provincia de Napo, por el sur con la provincia de Pastaza y al este con la provincia de Maynas perteneciente al Perú." ;
#     owl:sameAs <https://dbpedia.org/resource/Orellana_Province> .
#
# <http://WeatherTourist.org/destination/Tungurahua> a schema:State ;
#     rdfs:label " Tungurahua" ;
#     dbo:areaTotal 3.38625e+09 ;
#     rdfs:comment "La Provincia de Tungurahua es una de las 24 provincias que conforman la República del Ecuador, situada en el centro del país, en la zona geográfica conocida como región interandina o sierra, principalmente sobre la hoya de Patate. Su capital administrativa es la ciudad de Ambato, la cual además es su urbe más grande y poblada. Ocupa un territorio de unos 3222 km², siendo la provincia del país más pequeña por extensión. Limita al norte con Cotopaxi, al sur con Chimborazo, por el occidente con Bolívar, al sureste con Morona Santiago, al este con Pastaza y al noreste con Napo." ;
#     owl:sameAs <https://dbpedia.org/resource/Tungurahua_Province> .
#
# <http://WeatherTourist.org/destination/Pichincha> a schema:State ;
#     rdfs:label " Pichincha" ;
#     dbo:areaTotal 9.53591e+09 ;
#     rdfs:comment "La Provincia de Pichincha es una de las 24 provincias que conforman la República del Ecuador, situada en el centro norte del país, en la zona geográfica conocida como región interandina o sierra, principalmente sobre la hoya de Guayllabamba en el este y ramificaciones subandinas en el noroccidente. Su capital administrativa es la ciudad de Quito, la cual además es su urbe más poblada y la capital del país. Es también el principal centro comercial del país. Ocupa un territorio de unos 9692 km², siendo la undécima provincia del país por extensión. Limita al norte con Imbabura, al sur con Cotopaxi, por el occidente con Santo Domingo de los Tsáchilas, al noroccidente con Esmeraldas, al noreste con Sucumbios y al este con Napo." ;
#     owl:sameAs <https://dbpedia.org/resource/Pichincha_Province> .
#
# <http://WeatherTourist.org/destination/brokenclouds> a ns1:WeatherCondition ;
#     ns1:hasWeatherCondition "broken clouds" .
#
# <http://WeatherTourist.org/destination/Clouds> a ns1:WeatherState ;
#     ns1:hasWeatherCondition "Clouds" .
#
# <http://WeatherTourist.org/destination/lightrain> a ns1:WeatherCondition ;
#     ns1:hasWeatherCondition "light rain" .
#
# <http://WeatherTourist.org/destination/Rain> a ns1:WeatherState ;
#     ns1:hasWeatherCondition "Rain" .
#
# <http://WeatherTourist.org/destination/Ecuador> a schema:Country ;
#     rdfs:label " Ecuador" ;
#     owl:sameAs <http://dbpedia.org/resource/Ecuador> .

# %%
graph.serialize(destination="datosRDFSameAs_3.ttl")
# Out:
# <Graph identifier=Nd0a968f56a644d39b57cf0be8e13f488 (<class 'rdflib.graph.Graph'>)>

# %%
states = {
    'Azuay': 'http://dbpedia.org/resource/Azuay_Province',
    'Carchi': 'http://dbpedia.org/resource/Carchi_Province',
    'CotopaxiProvince': 'http://dbpedia.org/resource/Cotopaxi_Province',
    'EsmeraldasProvince': 'http://dbpedia.org/resource/Esmeraldas_Province',
    'Galapagos': 'http://dbpedia.org/resource/Galápagos_Province',
    'Guayas': 'http://dbpedia.org/resource/Guayas_Province',
    'Imbabura': 'http://dbpedia.org/resource/Imbabura_Province',
    'LojaProvince': 'http://dbpedia.org/resource/Loja_Province',
    'Manabi': 'http://dbpedia.org/resource/Manabí_Province',
    'Napo': 'http://dbpedia.org/resource/Napo_Province',
    'Orellana': 'http://dbpedia.org/resource/Orellana_Province',
    'Pichincha': 'http://dbpedia.org/resource/Pichincha_Province',
    'Tungurahua': 'http://dbpedia.org/resource/Tungurahua_Province'
}
for state in states:
    state_uri = URIRef(data + state)
    candidate_uri = URIRef(states[state])
    comment = get_comment(candidate_uri)
    areaTotal = get_areaTotal(candidate_uri)
    name = get_name(candidate_uri)
    graph.add((state_uri, rdfs.comment, Literal(comment)))  
    graph.add((state_uri, dbo.areaTotal, Literal(areaTotal, datatype=XSD.double)))
    graph.add((state_uri, foaf.name, Literal(name)))
# Out:
# select ?comment where {<http://dbpedia.org/resource/Azuay_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Azuay_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Azuay_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Azuay_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Azuay_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Azuay_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Carchi_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Carchi_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Carchi_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Carchi_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Carchi_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Carchi_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Cotopaxi_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Cotopaxi_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Cotopaxi_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Cotopaxi_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Cotopaxi_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Cotopaxi_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Esmeraldas_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Esmeraldas_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Esmeraldas_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Esmeraldas_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Esmeraldas_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Esmeraldas_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Galápagos_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Galápagos_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Galápagos_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Galápagos_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Galápagos_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Galápagos_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Guayas_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Guayas_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Guayas_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Guayas_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Guayas_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Guayas_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Imbabura_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Imbabura_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Imbabura_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Imbabura_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Imbabura_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Imbabura_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Loja_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Loja_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Loja_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Loja_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Loja_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Loja_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Manabí_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Manabí_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Manabí_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Manabí_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Manabí_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Manabí_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Napo_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Napo_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Napo_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Napo_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Napo_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Napo_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Orellana_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Orellana_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Orellana_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Orellana_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Orellana_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Orellana_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Pichincha_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Pichincha_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Pichincha_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Pichincha_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Pichincha_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Pichincha_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Tungurahua_Province does not look like a valid URI, trying to serialize this will break.
# select ?comment where {<http://dbpedia.org/resource/Tungurahua_Province> rdfs:comment ?comment. Optional{FILTER(LANG(?comment) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Tungurahua_Province does not look like a valid URI, trying to serialize this will break.
# select ?areaTotal where {<http://dbpedia.org/resource/Tungurahua_Province> dbo:areaTotal ?areaTotal. Optional{FILTER(LANG(?areaTotal) = "es")}} does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Tungurahua_Province does not look like a valid URI, trying to serialize this will break.
# select ?name where {<http://dbpedia.org/resource/Tungurahua_Province> foaf:name ?name. Optional{FILTER(LANG(?name) = "es")}} does not look like a valid URI, trying to serialize this will break.

# %%
graph.serialize(destination='datosRDFProvinces1.ttl')
# Out:
# <Graph identifier=Nd0a968f56a644d39b57cf0be8e13f488 (<class 'rdflib.graph.Graph'>)>
